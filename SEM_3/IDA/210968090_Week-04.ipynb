# %% [markdown]
# # SANTHOSH DARLA_210968090_IDA_WEEK-4_EXCERCISE :

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('Cereals1.xls')
df
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0           100%_Natural_Bran   Q    C       120        3    5      15    2.0
# 1                    All-Bran   K    C        70        4    1     260    9.0
# 2   All-Bran_with_Extra_Fiber   K    C        50        4    0     140   14.0
# 3              Almond_Delight   R    C       110        2    2     200    1.0
# 4     Apple_Cinnamon_Cheerios   G    C       110        2    2     180    1.5
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 71                    Triples   G    C       110        2    1     250    0.0
# 72                       Trix   G    C       110        1    1     140    0.0
# 73                 Wheat_Chex   R    C       100        3    1     230    3.0
# 74                   Wheaties   G    C       100        3    1     200    3.0
# 75        Wheaties_Honey_Gold   G    C       110        2    1     200    1.0
#
# ...

# %% [markdown]
# ## 1) Create a table with the 5-number summary of all the numeric attributes.

# %%
df.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   76.000000  76.000000  76.000000   76.000000  76.000000  76.000000
# mean   107.368421   2.526316   1.013158  160.065789   2.048684  14.723684
# std     19.139378   1.089020   1.013159   84.318813   2.219038   4.160444
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  132.500000   0.750000  12.000000
# 50%    110.000000   2.500000   1.000000  180.000000   1.750000  14.500000
# 75%    110.000000   3.000000   2.000000  212.500000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  76.000000   76.000000   76.000000  76.000000  76.000000  76.000000
# mean    6.934211   93.657895   28.289474   2.197368   1.030000   0.827500
# std     4.473136   68.502565   22.487813   0.832982   0.151438   0.227204
# ...

# %%
df[[ 'calories', 'protein', 'fat', 'sodium', 'fiber',
       'carbo', 'sugars', 'potass', 'vitamins']].describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   76.000000  76.000000  76.000000   76.000000  76.000000  76.000000
# mean   107.368421   2.526316   1.013158  160.065789   2.048684  14.723684
# std     19.139378   1.089020   1.013159   84.318813   2.219038   4.160444
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  132.500000   0.750000  12.000000
# 50%    110.000000   2.500000   1.000000  180.000000   1.750000  14.500000
# 75%    110.000000   3.000000   2.000000  212.500000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins
# count  76.000000   76.000000   76.000000
# mean    6.934211   93.657895   28.289474
# std     4.473136   68.502565   22.487813
# min    -1.000000   -1.000000    0.000000
# 25%     3.000000   40.000000   25.000000
# 50%     7.000000   90.000000   25.000000
# ...

# %% [markdown]
# ## 2) For each of the numeric attributes (proteins up to vitamins), identify and replace all           missing data (indicated with -1) with the arithmetic mean of the attribute.

# %%
df.dtypes
# Out:
# name         object
# mfr          object
# type         object
# calories      int64
# protein       int64
# fat           int64
# sodium        int64
# fiber       float64
# carbo       float64
# sugars        int64
# potass        int64
# vitamins      int64
# shelf         int64
# weight      float64
# cups        float64
# rating      float64
# dtype: object

# %%
for i in ['protein','fat','sodium','fiber','carbo','sugars','potass','vitamins']:
    df[i] = df[i].replace(-1,df[i].mean())
df
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0           100%_Natural_Bran   Q    C     120.0      3.0  5.0    15.0    2.0
# 1                    All-Bran   K    C      70.0      4.0  1.0   260.0    9.0
# 2   All-Bran_with_Extra_Fiber   K    C      50.0      4.0  0.0   140.0   14.0
# 3              Almond_Delight   R    C     110.0      2.0  2.0   200.0    1.0
# 4     Apple_Cinnamon_Cheerios   G    C     110.0      2.0  2.0   180.0    1.5
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 71                    Triples   G    C     110.0      2.0  1.0   250.0    0.0
# 72                       Trix   G    C     110.0      1.0  1.0   140.0    0.0
# 73                 Wheat_Chex   R    C     100.0      3.0  1.0   230.0    3.0
# 74                   Wheaties   G    C     100.0      3.0  1.0   200.0    3.0
# 75        Wheaties_Honey_Gold   G    C     110.0      2.0  1.0   200.0    1.0
#
# ...

# %% [markdown]
# ## 3) Create a table with the 5-number summary of all the numeric attributes after treating missing values. Do you think the strategy used in dealing with missing values was effective?

# %%
df.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   76.000000  76.000000  76.000000   76.000000  76.000000  76.000000
# mean   107.368421   2.526316   1.013158  160.065789   2.048684  14.930575
# std     19.139378   1.089020   1.013159   84.318813   2.219038   3.737575
# min     50.000000   1.000000   0.000000    0.000000   0.000000   7.000000
# 25%    100.000000   2.000000   0.000000  132.500000   0.750000  12.000000
# 50%    110.000000   2.500000   1.000000  180.000000   1.750000  14.861842
# 75%    110.000000   3.000000   2.000000  212.500000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  76.000000   76.000000   76.000000  76.000000  76.000000  76.000000
# mean    7.038608   96.148892   28.289474   2.197368   1.030000   0.827500
# std     4.377048   66.688658   22.487813   0.832982   0.151438   0.227204
# ...

# %%
print("Yes,dealing with missing values is effective")
# Out:
# Yes,dealing with missing values is effective

# %% [markdown]
# ## 4) For each of the numeric attributes (proteins up to vitamins), identify and replace all noisy data with the median of attribute.

# %%
def remove_outlier_IQR(df):
    Q1=df.quantile(0.25)
    Q3=df.quantile(0.75)
    IQR=Q3-Q1
    df_final=df[~((df<(Q1-1.5*IQR)) | (df>(Q3+1.5*IQR)))]
    return df_final

# %%
df[[ 'calories', 'protein', 'fat', 'sodium', 'fiber',
       'carbo', 'sugars', 'potass', 'vitamins']]=remove_outlier_IQR(df[[ 'calories', 'protein', 'fat', 'sodium', 'fiber',
       'carbo', 'sugars', 'potass', 'vitamins']])

# %%
for x in [ 'calories', 'protein', 'fat', 'sodium', 'fiber',
       'carbo', 'sugars', 'potass', 'vitamins']:
    df[x] = df[x].replace(np.nan,df[x].median())

# %%
df
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0           100%_Natural_Bran   Q    C     120.0      3.0  5.0   190.0    2.0
# 1                    All-Bran   K    C     110.0      4.0  1.0   260.0    1.5
# 2   All-Bran_with_Extra_Fiber   K    C     110.0      4.0  0.0   140.0    1.5
# 3              Almond_Delight   R    C     110.0      2.0  2.0   200.0    1.0
# 4     Apple_Cinnamon_Cheerios   G    C     110.0      2.0  2.0   180.0    1.5
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 71                    Triples   G    C     110.0      2.0  1.0   250.0    0.0
# 72                       Trix   G    C     110.0      1.0  1.0   140.0    0.0
# 73                 Wheat_Chex   R    C     100.0      3.0  1.0   230.0    3.0
# 74                   Wheaties   G    C     100.0      3.0  1.0   200.0    3.0
# 75        Wheaties_Honey_Gold   G    C     110.0      2.0  1.0   200.0    1.0
#
# ...

# %% [markdown]
# ## 5) Create a table with the 5-number summary of all the numeric attributes after treating noisy values. Do you think the strategy used in dealing with noisy values was effective?

# %%
df.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   76.000000  76.000000  76.000000   76.000000  76.000000  76.000000
# mean   107.236842   2.381579   1.013158  187.171053   1.785526  14.930575
# std      8.099166   0.878895   1.013159   53.487291   1.520939   3.737575
# min     90.000000   1.000000   0.000000   45.000000   0.000000   7.000000
# 25%    100.000000   2.000000   0.000000  150.000000   0.750000  12.000000
# 50%    110.000000   2.000000   1.000000  190.000000   1.500000  14.861842
# 75%    110.000000   3.000000   2.000000  212.500000   3.000000  17.000000
# max    120.000000   4.000000   5.000000  320.000000   6.000000  23.000000
#
#           sugars      potass  vitamins      shelf     weight       cups  \
# count  76.000000   76.000000      76.0  76.000000  76.000000  76.000000
# mean    7.038608   83.912050      25.0   2.197368   1.030000   0.827500
# std     4.377048   45.034796       0.0   0.832982   0.151438   0.227204
# ...

# %%
print("Yes,dealing with  noisy values is effective")
# Out:
# Yes,dealing with  noisy values is effective

# %% [markdown]
# ## 6) Cross tabulate the type of cereal (hot vs cold) against the manufacturer

# %%
pd.crosstab(df['type'],df['mfr'])
# Out:
# mfr   A   G   K  N  P  Q  R
# type
# C     0  22  23  4  9  7  8
# H     1   0   0  1  0  1  0

# %% [markdown]
# ## 7) Which is the cereal with the best rating, worst rating?

# %%
print("Cereal with best rating:")
df.loc[df['rating']==df['rating'].max()].name
# Out:
# Cereal with best rating:
# 2    All-Bran_with_Extra_Fiber
# Name: name, dtype: object

# %%
print("Cereal with wrost rating:")
df.loc[df['rating']==df['rating'].min()].name
# Out:
# Cereal with wrost rating:
# 9    Cap'n'Crunch
# Name: name, dtype: object

# %% [markdown]
# ## 8) Plot a side-by-side boxplot comparing the consumer rating of hot vs. cold cereals.

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
fig, axs = plt.subplots(figsize = (10,7.5))
sns.boxplot(x=df['type'],y=df['rating'],ax=axs)

# %% [markdown]
# ## 9) Is there a relation between sugars, calories, carbs, and fat?

# %%
plt.figure(figsize = (10,7))
sns.heatmap(df[[ 'calories', 'fat','carbo', 'sugars']].corr(), annot = True, cmap="Blues",linecolor='purple')

# %% [markdown]
# ## 10) Which manufacturers produce cereal with highest calories?

# %%
df.loc[df['calories']==df['calories'].max()].mfr
# Out:
# 45    K
# Name: mfr, dtype: object

# %%
df['mfr'][df['rating'].nlargest(1).index]
# Out:
# 2    K
# Name: mfr, dtype: object

# %% [markdown]
# ## 11) Use correlation tests and visualization to identify if the two variables calories and  consumer rating associated?

# %%
plt.scatter(y=df['calories'],x=df['rating'],color='purple')
plt.gca().update(dict(title='SCATTER PLOT FOR CALORIES AND RATING', xlabel='calories', ylabel='rating'))
# Out:
# [Text(0.5, 1.0, 'SCATTER PLOT FOR CALORIES AND RATING'),
#  Text(0.5, 0, 'calories'),
#  Text(0, 0.5, 'rating')]

# %%
plt.figure(figsize = (3,2))
sns.heatmap(df[['calories','rating']].corr(), annot = True, cmap="Blues")
plt.gca().update(dict(title='HEAT MAP FOR CALORIES AND RATING'))
# Out:
# [Text(0.5, 1.0, 'HEAT MAP FOR CALORIES AND RATING')]

# %% [markdown]
# # Tried ANOVA - because dealing with more than two classes

# %%
import scipy.stats as stats

df1=df.loc[0:1]
stats.ttest_ind(df1['calories'],df['rating'])
# Out:
# Ttest_indResult(statistic=7.3763221711734674, pvalue=1.704283780446464e-10)

# %% [markdown]
# ## 12) Use correlation tests and visualization to identify if the two variables shelf and consumer rating associated?

# %% [markdown]
# ## ANOVA

# %%
stats.f_oneway(df['shelf'],df['rating'])
# Out:
# F_onewayResult(statistic=638.4347192955644, pvalue=6.423036106528478e-56)

# %%
plt.figure(figsize = (3,2))
sns.heatmap(df[['shelf','rating']].corr(), annot = True, cmap="Greens")
plt.gca().update(dict(title='HEAT MAP FOR SHELF AND RATING'))
# Out:
# [Text(0.5, 1.0, 'HEAT MAP FOR SHELF AND RATING')]

# %%
df.groupby('shelf').mean().rating
# Out:
# shelf
# 1    46.145439
# 2    34.972827
# 3    44.557662
# Name: rating, dtype: float64

# %% [markdown]
# ## Q13--Is there a relation between manufacturer and rating?

# %%
pd.crosstab(df['rating'],df['mfr']).head()
# Out:
# mfr        A  G  K  N  P  Q  R
# rating
# 18.042851  0  0  0  0  0  1  0
# 19.823573  0  1  0  0  0  0  0
# 21.871292  0  0  0  0  0  1  0
# 22.396513  0  1  0  0  0  0  0
# 22.736446  0  1  0  0  0  0  0

# %%
df.groupby('mfr').mean().rating
# Out:
# mfr
# A    54.850917
# G    34.485852
# K    44.038462
# N    67.881686
# P    41.705744
# Q    42.915990
# R    41.542997
# Name: rating, dtype: float64

# %%
df.groupby('mfr').max().rating
# Out:
# mfr
# A    54.850917
# G    51.592193
# K    93.704912
# N    74.472949
# P    53.371007
# Q    63.005645
# R    49.787445
# Name: rating, dtype: float64

# %%
df.groupby('mfr').min().rating
# Out:
# mfr
# A    54.850917
# G    19.823573
# K    29.924285
# N    59.363993
# P    28.025765
# Q    18.042851
# R    34.139765
# Name: rating, dtype: float64

# %%
df.groupby('mfr').median().rating
# Out:
# mfr
# A    54.850917
# G    36.181877
# K    40.560159
# N    68.235885
# P    40.917047
# Q    47.419974
# R    41.721976
# Name: rating, dtype: float64

# %% [markdown]
# ## Q14-- Which nutrients are essential for a good rating for a cereal?

# %%
plt.figure(figsize = (10,7))
sns.heatmap(df[[ 'calories', 'protein', 'fat', 'sodium', 'fiber','carbo', 'sugars', 'potass', 'vitamins',
                'rating']].corr(), annot = True, cmap="Purples")
plt.gca().update(dict(title='HEAT MAP FOR CREREAL AND RATING'))
# Out:
# [Text(0.5, 1.0, 'HEAT MAP FOR CREREAL AND RATING')]

# %% [markdown]
# # Reasoning :
# ## Here there is negative correlation i.e inversly proportional so we can conclude that ,
# ## "Lesser the Sugar,  heigher the Rating"

# %% [markdown]
# ## Q15--Design a Linear regression model to predict the rating of a cereal based on top 3 related nutrients. Tabulate the accuracy of the model using an 80, 20 split?

# %%
df1 = df[['rating']]
df2=df[['sugars','fat','protein']]

model =LinearRegression().fit(df2,df1)

pd.DataFrame(model.predict(df2))
# Out:
#             0
# 0   26.592427
# 1   56.325762
# 2   70.156136
# 3   33.733636
# 4   29.987506
# ..        ...
# 71  47.564010
# 72  24.452485
# 73  53.817951
# 74  53.817951
# 75  38.198686
#
# [76 rows x 1 columns]
